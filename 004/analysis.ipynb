# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import os,glob
import PIL

# %%
#Auto reload
# %load_ext autoreload
# %autoreload 2

from DataLoader import PokeBall
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import PIL.Image


transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((64,64)),
    torchvision.transforms.ToTensor()
])
transforms(PIL.Image.open('dataset\\Seaking\\4e2aa3e191214f4bac27bb1b927d8fc7.jpg'))
# Out:
# tensor([[[0.0275, 0.0275, 0.0353,  ..., 0.0118, 0.0118, 0.0118],
#          [0.0275, 0.0275, 0.0314,  ..., 0.0157, 0.0157, 0.0118],
#          [0.0275, 0.0275, 0.0314,  ..., 0.0118, 0.0118, 0.0118],
#          ...,
#          [0.9804, 0.9804, 0.9804,  ..., 0.9804, 0.9804, 0.9569],
#          [0.9804, 0.9804, 0.9804,  ..., 0.9882, 0.9843, 0.9765],
#          [0.9804, 0.9804, 0.9804,  ..., 0.9882, 0.9647, 0.9725]],
#
#         [[0.3529, 0.3529, 0.3490,  ..., 0.4863, 0.4863, 0.4863],
#          [0.3490, 0.3490, 0.3490,  ..., 0.4902, 0.4902, 0.4863],
#          [0.3490, 0.3451, 0.3490,  ..., 0.4902, 0.4902, 0.4902],
#          ...,
#          [0.9804, 0.9804, 0.9804,  ..., 0.9765, 0.9765, 0.9843],
#          [0.9804, 0.9804, 0.9804,  ..., 0.9765, 0.9804, 0.9804],
#          [0.9804, 0.9804, 0.9804,  ..., 0.9686, 0.9843, 0.9765]],
#
#         [[0.5647, 0.5647, 0.5647,  ..., 0.6078, 0.6078, 0.6078],
#          [0.5608, 0.5608, 0.5647,  ..., 0.6118, 0.6118, 0.6078],
# ...

# %%
all_files = glob.glob('dataset/*/*.jpg')
while True:
    x = PIL.Image.open(np.random.choice(all_files))
    
    if x.mode != 'RGB':
        print(x.mode)
        break
# Out:
# L

# %%
tmp = x.convert('RGB')
tmp = tmp.convert('RGB')
np.array(tmp).shape
# Out:
# (397, 450, 3)

# %%
torchvision.io.image.read_image('dataset\Voltorb\d8d3a60ebb3548a3afb37c2ee81217bb.jpg')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\V'
# <>:1: SyntaxWarning: invalid escape sequence '\V'
# C:\Users\bence\AppData\Local\Temp\ipykernel_1760\1981377489.py:1: SyntaxWarning: invalid escape sequence '\V'
#   torchvision.io.image.read_image('dataset\Voltorb\d8d3a60ebb3548a3afb37c2ee81217bb.jpg')
# tensor([[[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
# ...

# %%
loader = PokeBall()
batch = loader()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 2
#       1 loader = PokeBall()
# ----> 2 batch = loader()
#
# File d:\Personal-projects\004\DataLoader.py:49, in PokeBall.__call__(self)
#      48 def __call__(self):
# ---> 49     return self.__next__()
#
# File d:\Personal-projects\004\DataLoader.py:42, in PokeBall.__next__(self)
#      40     images, labels = self.__get_batch__()
#      41     self.currentStep += self.batch_size
# ---> 42     return self.__transformBatch__(images), labels
#      43 else:
#      44     self.currentStep = 0
#
# File d:\Personal-projects\004\DataLoader.py:35, in PokeBall.__transformBatch__(self, imgs)
#      34 def __transformBatch__(self, imgs):
# ---> 35     self.transform(imgs)
#      36     return imgs
#
# ...

# %%
img = torchvision.io.read_image(SampleImagePath)

# %%
plt.imshow(img.permute(1, 2, 0))
